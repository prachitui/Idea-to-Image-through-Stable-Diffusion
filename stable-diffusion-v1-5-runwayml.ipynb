# %% [markdown]
# ## Stable Diffusion v1-5 - by RunwayML

# %% [markdown]
# 1. Model Name: stable-diffusion-v1-5
# 2. Model type: Diffusion-based text-to-image generation model
# 3. Model Description: Generate/ modify images w/ text prompts.
# 4. Link: https://huggingface.co/runwayml/stable-diffusion-v1-5

# %%
# install dependencies
# !pip install diffusers
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
sd_pipeline = StableDiffusionPipeline.from_pretrained(model_id,
                                                      torch_dtype=torch.float16)
sd_pipeline = sd_pipeline.to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2024-07-08 13:26:45.178972: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-08 13:26:45.179116: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-08 13:26:45.392649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...

# %%
def get_completion_sd(prompt):
  negative_prompt = """
  simple background, duplicate, low quality, lowest quality,
  bad anatomy, bad proportions, extra digits, lowres, username,
  artist name, error, duplicate, watermark, signature, text,
  extra digit, fewer digits, worst quality, jpeg artifacts, blurry
  """
  return sd_pipeline(prompt, negative_prompt=negative_prompt).images[0]

# %%
#let's prompt

# prompt = "astronaut, riding a horse, on mars, human colony"
# prompt = "children, playing in disneyland, view from a distance"
prompt = """baby llama, wearing red muffler,
grazing, open field, sunset
"""
print(prompt)
sd_image = get_completion_sd(prompt)
sd_image.save("./llama.jpg")
# Out:
# baby llama, wearing red muffler,
# grazing, open field, sunset
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import PIL # We will import the packages at "use-time (just for this kernel)

PIL.Image.open("/kaggle/working/llama.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
#let's prompt

# prompt = "astronaut, riding a horse, on mars, human colony"
# prompt = "children, playing in disneyland, view from a distance"
prompt = """Water body in grand canyon,
, beautiful, sunset
"""
print(prompt)
sd_image = get_completion_sd(prompt)
sd_image.save("./GC.jpg")
# Out:
# Water body in grand canyon,
# , beautiful, sunset
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
PIL.Image.open("/kaggle/working/GC.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
#let's prompt

# prompt = "astronaut, riding a horse, on mars, human colony"
# prompt = "children, playing in disneyland, view from a distance"
prompt = """Ocean with yachts,
happy, beautiful, sunrise
"""
print(prompt)
sd_image = get_completion_sd(prompt)
sd_image.save("./Vacation2.jpg")
# Out:
# Ocean with yachts,
# happy, beautiful, sunrise
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
PIL.Image.open("/kaggle/working/Vacation2.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
#let's prompt

# prompt = "astronaut, riding a horse, on mars, human colony"
# prompt = "children, playing in disneyland, view from a distance"
prompt = """Mars,
planet, beautiful
"""
print(prompt)
sd_image = get_completion_sd(prompt)
sd_image.save("./Mars.jpg")
# Out:
# Mars,
# planet, beautiful
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
PIL.Image.open("/kaggle/working/Mars.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
